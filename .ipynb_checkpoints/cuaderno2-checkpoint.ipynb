# %%
import pandas as pd

# %%
data = pd.read_csv('Data/mdata.csv')

# %%
#pip install pygwalker

# %%
import pygwalker as pyg

# %%
pyg.walk(data)
# Out:
# Box(children=(HTML(value='\n<div id="ifr-pyg-000650bd2599314bd6x7PM2XYlLUqkCo" style="height: auto">\n    <hea…
# <script>
#     window.addEventListener("message", function(event) {
#         const backgroundMap = {
#             "dark": "hsl(240 10% 3.9%)",
#             "light": "hsl(0 0 100%)",
#         };
#         const colorMap = {
#             "dark": "hsl(0 0% 98%)",
#             "light": "hsl(240 10% 3.9%)",
#         };
#         if (event.data.action === "changeAppearance" && event.data.gid === "000650bd2599314bd6x7PM2XYlLUqkCo") {
#             var iframe = document.getElementById("gwalker-000650bd2599314bd6x7PM2XYlLUqkCo");
#             iframe.style.background  = backgroundMap[event.data.appearance];
#             iframe.style.color = colorMap[event.data.appearance];
#         }
#     });
# </script>
